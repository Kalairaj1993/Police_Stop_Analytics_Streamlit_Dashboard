# %%
import pandas as pd
from datetime import datetime

# %%
pip install SQLAlchemy psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import psycopg2

try:
    conn = psycopg2.connect(
        dbname="police",  # Check this name
        user="rajuser",
        password="Miezb4Wu9cf3VZ30YCBedzlyYW1hzmFm",
        host="dpg-d0ka3bruibrs739bsct0-a.singapore-postgres.render.com",
        port="5432"
    )
    print("Connected successfully")
except Exception as e:
    print("Connection failed:", e)

cursor = conn.cursor()
# Out:
# Connected successfully

# %%
sheet_id = "16qEUKckLFy7j1qoSd1bSQURn9QXDb6ffSBAWzRkPsSg"
sheet_name = "police_stops"

url = f"https://docs.google.com/spreadsheets/d/16qEUKckLFy7j1qoSd1bSQURn9QXDb6ffSBAWzRkPsSg/gviz/tq?tqx=out:csv&sheet=police_stops"

df = pd.read_csv (url)
# Out:
# C:\Users\DHANALAKSHMI TRADERS\AppData\Local\Temp\ipykernel_10664\3639183365.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv (url)

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
db_url="postgresql://rajuser:Miezb4Wu9cf3VZ30YCBedzlyYW1hzmFm@dpg-d0ka3bruibrs739bsct0-a.singapore-postgres.render.com/police"

# %%
from sqlalchemy import create_engine, inspect
engine=create_engine(db_url)

# %%
df.to_sql('police_stops',engine,index=False,if_exists='replace')
# Out:
# 538

# %%
query='select * from police_stops'
df=pd.read_sql(query,engine)

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
df.dropna(axis=1, how='all', inplace=True)

df.fillna({
    'driver_age': df['driver_age'].median(),
    'search_type': 'None',
    'stop_duration':'unknown',
    'violation':'unknown',
    'stop_outcome':'unknown',
}, inplace=True)

df['timestamp'] = pd.to_datetime(df['stop_date'] +' '+ df['stop_time'])

# %%
conn.rollback()

cursor.execute("SELECT current_database();")
print(cursor.fetchone())
# Out:
# ('police',)

# %%
cursor.execute("""
    CREATE TABLE police_stops (
        id SERIAL PRIMARY KEY,
        stop_date DATE,
        stop_time TIME,
        country_name VARCHAR(100),
        driver_gender VARCHAR(10),
        driver_age INT,
        driver_race VARCHAR(50),
        violation VARCHAR(100),
        search_conducted BOOLEAN,
        search_type VARCHAR(100),
        stop_outcome VARCHAR(100),
        drugs_related_stop BOOLEAN,
        stop_duration VARCHAR(50),
        vehicle_number VARCHAR(50),
        timestamp TIMESTAMP
    );
""")
conn.commit()

# %%
#Data Cleaning

df.dropna(axis=1, how='all', inplace=True)

df.fillna({
    'driver_age': df['driver_age'].median(),
    'search_type': 'None',
    'stop_duration':'unknown',
    'violation':'unknown',
    'stop_outcome':'unknown',
}, inplace=True)

# Create Timestamp column
df['timestamp'] = pd.to_datetime(df['stop_date'] +' '+ df['stop_time'])

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
# Coverted stop_date to correct format (YYYY-MM-DD)
df['stop_date']= pd.to_datetime(df['stop_date'], errors='coerce').dt.strftime('%Y-%m-%d')

# Coverted stop_time is in correct format (HH:MM:SS)
df['stop_date']= pd.to_datetime(df['stop_date'], format='%H:%M:%S', errors='coerce').dt.strftime('H:%M:%S')

# %%
df
# Out:
#       stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0           NaN   0:00:00       Canada             M              59
# 1           NaN   0:01:00        India             M              35
# 2           NaN   0:02:00          USA             M              26
# 3           NaN   0:03:00       Canada             M              26
# 4           NaN   0:04:00       Canada             M              62
# ...         ...       ...          ...           ...             ...
# 65533       NaN  12:13:00        India             F              54
# 65534       NaN  12:14:00       Canada             F              18
# 65535       NaN  12:15:00          USA             M              27
# 65536       NaN  12:16:00       Canada             F              49
# 65537       NaN  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
df = df.where(pd.notnull(df), None)

# %%
import streamlit as st

insert_query = """
    INSERT INTO police_stops (
    stop_date, stop_time, country_name, driver_gender, driver_age, driver_race,
    violation, search_conducted, search_type, stop_outcome,
    drugs_related_stop, stop_duration, vehicle_number
    ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# Rollback any previous failed transaction before starting
conn.rollback()

# Iterate DataFrame and Insert Rows
for index, row in df.iterrows():
    values_to_insert = (
        row['stop_date'],
        row['stop_time'],
        row.get('country_name'),
        row.get('driver_gender'),
        int(row['driver_age']) if pd.notnull(row.get('driver_age')) else None,
        row.get('driver_race'),
        row.get('violation'),
        row.get('search_conducted'),
        row.get('search_type'),
        row.get('stop_outcome'),
        row.get('drugs_related_stop'),
        row.get('stop_duration'),
        row.get('vehicle_number') or f'VEH{index}'
    )

conn.commit()

# %%
cursor.close()
conn.close()

# %%
import pandas as pd
from datetime import datetime

# %%
pip install SQLAlchemy psycopg2
# Out:
# Requirement already satisfied: SQLAlchemy in c:\users\kalairaj\appdata\local\programs\python\python312\lib\site-packages (2.0.41)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: psycopg2 in c:\users\kalairaj\appdata\local\programs\python\python312\lib\site-packages (2.9.10)
# Requirement already satisfied: greenlet>=1 in c:\users\kalairaj\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy) (3.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\kalairaj\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy) (4.13.2)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import psycopg2

try:
    conn = psycopg2.connect(
        dbname="policestops",  
        user="rajuser",
        password="password",
        host="host",
        port="5432"
    )
    print("Connected successfully")
except Exception as e:
    print("Connection failed:", e)
# Out:
# Connected successfully

# %%
cursor = conn.cursor()

# %%
sheet_id = "16qEUKckLFy7j1qoSd1bSQURn9QXDb6ffSBAWzRkPsSg"
sheet_name = "police_stops"

url = f"https://docs.google.com/spreadsheets/d/16qEUKckLFy7j1qoSd1bSQURn9QXDb6ffSBAWzRkPsSg/gviz/tq?tqx=out:csv&sheet=police_stops"

df = pd.read_csv (url)
# Out:
# C:\Users\KALAIRAJ\AppData\Local\Temp\ipykernel_18872\3639183365.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv (url)

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 0              19       Asian     Drunk Driving  Speeding              True
# 1              58       Other             Other     Other             False
# 2              76       Black  Signal Violation  Speeding             False
# 3              76       Black          Speeding       DUI              True
# 4              75       Other          Speeding     Other             False
# ...           ...         ...               ...       ...               ...
# 65533          48       Black             Other     Other             False
# 65534          35    Hispanic          Seatbelt     Other              True
# 65535          41       Asian          Seatbelt       DUI              True
# 65536          63       Black          Seatbelt     Other             False
# 65537          32       Other          Seatbelt  Speeding              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 1      Vehicle Search       Arrest         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 4      Vehicle Search       Arrest         True     16-30 Min
# ...               ...          ...          ...           ...
# 65533  Vehicle Search       Arrest         True     16-30 Min
# 65534  Vehicle Search       Ticket        False     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
# 65536             NaN      Warning         True      0-15 Min
# 65537             NaN       Ticket         True     16-30 Min
#
#        drugs_related_stop vehicle_number
# 0                    True     UP76DY3473
# 1                    True     RJ83PZ4441
# 2                    True     RJ32OM7264
# 3                    True     RJ76TI3807
# 4                   False     WB63BB8305
# ...                   ...            ...
# 65533               False     DL56GW6568
# 65534                True     TN73EO7098
# 65535                True     GJ33MX8328
# 65536                True     KA24UZ8488
# 65537               False     UP89PT2924
#
# [65538 rows x 16 columns]

# %%
db_url="data base url"

# %%
from sqlalchemy import create_engine, inspect
engine=create_engine(db_url)

# %%
df.to_sql('police_stops',engine,index=False,if_exists='replace')
# Out:
# 538

# %%
query='select * from police_stops'
df=pd.read_sql(query,engine)

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 0              19       Asian     Drunk Driving  Speeding              True
# 1              58       Other             Other     Other             False
# 2              76       Black  Signal Violation  Speeding             False
# 3              76       Black          Speeding       DUI              True
# 4              75       Other          Speeding     Other             False
# ...           ...         ...               ...       ...               ...
# 65533          48       Black             Other     Other             False
# 65534          35    Hispanic          Seatbelt     Other              True
# 65535          41       Asian          Seatbelt       DUI              True
# 65536          63       Black          Seatbelt     Other             False
# 65537          32       Other          Seatbelt  Speeding              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 1      Vehicle Search       Arrest         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 4      Vehicle Search       Arrest         True     16-30 Min
# ...               ...          ...          ...           ...
# 65533  Vehicle Search       Arrest         True     16-30 Min
# 65534  Vehicle Search       Ticket        False     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
# 65536            None      Warning         True      0-15 Min
# 65537            None       Ticket         True     16-30 Min
#
#        drugs_related_stop vehicle_number
# 0                    True     UP76DY3473
# 1                    True     RJ83PZ4441
# 2                    True     RJ32OM7264
# 3                    True     RJ76TI3807
# 4                   False     WB63BB8305
# ...                   ...            ...
# 65533               False     DL56GW6568
# 65534                True     TN73EO7098
# 65535                True     GJ33MX8328
# 65536                True     KA24UZ8488
# 65537               False     UP89PT2924
#
# [65538 rows x 16 columns]

# %%
df.dropna(axis=1, how='all', inplace=True)

df.fillna({
    'driver_age': df['driver_age'].median(),
    'search_type': 'None',
    'stop_duration':'unknown',
    'violation':'unknown',
    'stop_outcome':'unknown',
}, inplace=True)

df['timestamp'] = pd.to_datetime(df['stop_date'] +' '+ df['stop_time'])

# %%
print(df.columns)
# Out:
# Index(['stop_date', 'stop_time', 'country_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'drugs_related_stop', 'vehicle_number',
#        'timestamp'],
#       dtype='object')

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 0              19       Asian     Drunk Driving  Speeding              True
# 1              58       Other             Other     Other             False
# 2              76       Black  Signal Violation  Speeding             False
# 3              76       Black          Speeding       DUI              True
# 4              75       Other          Speeding     Other             False
# ...           ...         ...               ...       ...               ...
# 65533          48       Black             Other     Other             False
# 65534          35    Hispanic          Seatbelt     Other              True
# 65535          41       Asian          Seatbelt       DUI              True
# 65536          63       Black          Seatbelt     Other             False
# 65537          32       Other          Seatbelt  Speeding              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 1      Vehicle Search       Arrest         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 4      Vehicle Search       Arrest         True     16-30 Min
# ...               ...          ...          ...           ...
# 65533  Vehicle Search       Arrest         True     16-30 Min
# 65534  Vehicle Search       Ticket        False     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
# 65536            None      Warning         True      0-15 Min
# 65537            None       Ticket         True     16-30 Min
#
#        drugs_related_stop vehicle_number           timestamp
# 0                    True     UP76DY3473 2020-01-01 00:00:00
# 1                    True     RJ83PZ4441 2020-01-01 00:01:00
# 2                    True     RJ32OM7264 2020-01-01 00:02:00
# 3                    True     RJ76TI3807 2020-01-01 00:03:00
# 4                   False     WB63BB8305 2020-01-01 00:04:00
# ...                   ...            ...                 ...
# 65533               False     DL56GW6568 2020-02-15 12:13:00
# 65534                True     TN73EO7098 2020-02-15 12:14:00
# 65535                True     GJ33MX8328 2020-02-15 12:15:00
# 65536                True     KA24UZ8488 2020-02-15 12:16:00
# 65537               False     UP89PT2924 2020-02-15 12:17:00
#
# [65538 rows x 17 columns]

# %%
#Data Cleaning

df.dropna(axis=1, how='all', inplace=True)

df.fillna({
    'driver_age': df['driver_age'].median(),
    'search_type': 'None',
    'stop_duration':'unknown',
    'violation':'unknown',
    'stop_outcome':'unknown',
}, inplace=True)

# Create Timestamp column
df['timestamp'] = pd.to_datetime(df['stop_date'] +' '+ df['stop_time'])

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 0              19       Asian     Drunk Driving  Speeding              True
# 1              58       Other             Other     Other             False
# 2              76       Black  Signal Violation  Speeding             False
# 3              76       Black          Speeding       DUI              True
# 4              75       Other          Speeding     Other             False
# ...           ...         ...               ...       ...               ...
# 65533          48       Black             Other     Other             False
# 65534          35    Hispanic          Seatbelt     Other              True
# 65535          41       Asian          Seatbelt       DUI              True
# 65536          63       Black          Seatbelt     Other             False
# 65537          32       Other          Seatbelt  Speeding              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 1      Vehicle Search       Arrest         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 4      Vehicle Search       Arrest         True     16-30 Min
# ...               ...          ...          ...           ...
# 65533  Vehicle Search       Arrest         True     16-30 Min
# 65534  Vehicle Search       Ticket        False     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
# 65536            None      Warning         True      0-15 Min
# 65537            None       Ticket         True     16-30 Min
#
#        drugs_related_stop vehicle_number           timestamp
# 0                    True     UP76DY3473 2020-01-01 00:00:00
# 1                    True     RJ83PZ4441 2020-01-01 00:01:00
# 2                    True     RJ32OM7264 2020-01-01 00:02:00
# 3                    True     RJ76TI3807 2020-01-01 00:03:00
# 4                   False     WB63BB8305 2020-01-01 00:04:00
# ...                   ...            ...                 ...
# 65533               False     DL56GW6568 2020-02-15 12:13:00
# 65534                True     TN73EO7098 2020-02-15 12:14:00
# 65535                True     GJ33MX8328 2020-02-15 12:15:00
# 65536                True     KA24UZ8488 2020-02-15 12:16:00
# 65537               False     UP89PT2924 2020-02-15 12:17:00
#
# [65538 rows x 17 columns]

# %%
# Coverted stop_date to correct format (YYYY-MM-DD)
df['stop_date']= pd.to_datetime(df['stop_date'], errors='coerce').dt.strftime('%Y-%m-%d')

# Coverted stop_time is in correct format (HH:MM:SS)
df['stop_date']= pd.to_datetime(df['stop_date'], format='%H:%M:%S', errors='coerce').dt.strftime('H:%M:%S')

# %%
df
# Out:
#       stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0           NaN   0:00:00       Canada             M              59
# 1           NaN   0:01:00        India             M              35
# 2           NaN   0:02:00          USA             M              26
# 3           NaN   0:03:00       Canada             M              26
# 4           NaN   0:04:00       Canada             M              62
# ...         ...       ...          ...           ...             ...
# 65533       NaN  12:13:00        India             F              54
# 65534       NaN  12:14:00       Canada             F              18
# 65535       NaN  12:15:00          USA             M              27
# 65536       NaN  12:16:00       Canada             F              49
# 65537       NaN  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 0              19       Asian     Drunk Driving  Speeding              True
# 1              58       Other             Other     Other             False
# 2              76       Black  Signal Violation  Speeding             False
# 3              76       Black          Speeding       DUI              True
# 4              75       Other          Speeding     Other             False
# ...           ...         ...               ...       ...               ...
# 65533          48       Black             Other     Other             False
# 65534          35    Hispanic          Seatbelt     Other              True
# 65535          41       Asian          Seatbelt       DUI              True
# 65536          63       Black          Seatbelt     Other             False
# 65537          32       Other          Seatbelt  Speeding              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 1      Vehicle Search       Arrest         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 4      Vehicle Search       Arrest         True     16-30 Min
# ...               ...          ...          ...           ...
# 65533  Vehicle Search       Arrest         True     16-30 Min
# 65534  Vehicle Search       Ticket        False     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
# 65536            None      Warning         True      0-15 Min
# 65537            None       Ticket         True     16-30 Min
#
#        drugs_related_stop vehicle_number           timestamp
# 0                    True     UP76DY3473 2020-01-01 00:00:00
# 1                    True     RJ83PZ4441 2020-01-01 00:01:00
# 2                    True     RJ32OM7264 2020-01-01 00:02:00
# 3                    True     RJ76TI3807 2020-01-01 00:03:00
# 4                   False     WB63BB8305 2020-01-01 00:04:00
# ...                   ...            ...                 ...
# 65533               False     DL56GW6568 2020-02-15 12:13:00
# 65534                True     TN73EO7098 2020-02-15 12:14:00
# 65535                True     GJ33MX8328 2020-02-15 12:15:00
# 65536                True     KA24UZ8488 2020-02-15 12:16:00
# 65537               False     UP89PT2924 2020-02-15 12:17:00
#
# [65538 rows x 17 columns]

# %%
df = df.where(pd.notnull(df), None)

# %%
import streamlit as st

insert_query = """
    INSERT INTO police_stops (
    stop_date, stop_time, country_name, driver_gender, driver_age, driver_race,
    violation, search_conducted, search_type, stop_outcome,
    drugs_related_stop, stop_duration, vehicle_number, timestamp
    ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# Rollback any previous failed transaction before starting
conn.rollback()

# Iterate DataFrame and Insert Rows
for index, row in df.iterrows():
    values_to_insert = (
        row['stop_date'],
        row['stop_time'],
        row.get('country_name'),
        row.get('driver_gender'),
        int(row['driver_age']) if pd.notnull(row.get('driver_age')) else None,
        row.get('driver_race'),
        row.get('violation'),
        row.get('search_conducted'),
        row.get('search_type'),
        row.get('stop_outcome'),
        row.get('drugs_related_stop'),
        row.get('stop_duration'),
        row.get('vehicle_number') or f"VEH{index}'s",
        row.get('timestamp'),
    )
    print(f"Row {index}: Number of values = {len(values_to_insert)}") 

conn.commit()
# Out:
# Row 0: Number of values = 14
# Row 1: Number of values = 14
# Row 2: Number of values = 14
# Row 3: Number of values = 14
# Row 4: Number of values = 14
# Row 5: Number of values = 14
# Row 6: Number of values = 14
# Row 7: Number of values = 14
# Row 8: Number of values = 14
# Row 9: Number of values = 14
# Row 10: Number of values = 14
# Row 11: Number of values = 14
# Row 12: Number of values = 14
# Row 13: Number of values = 14
# Row 14: Number of values = 14
# Row 15: Number of values = 14
# Row 16: Number of values = 14
# Row 17: Number of values = 14
# Row 18: Number of values = 14
# Row 19: Number of values = 14
# Row 20: Number of values = 14
# Row 21: Number of values = 14
# Row 22: Number of values = 14
# Row 23: Number of values = 14
# Row 24: Number of values = 14
# Row 25: Number of values = 14
# Row 26: Number of values = 14
# Row 27: Number of values = 14
# Row 28: Number of values = 14
# Row 29: Number of values = 14
# Row 30: Number of values = 14
# Row 31: Number of values = 14
# Row 32: Number of values = 14
# Row 33: Number of values = 14
# Row 34: Number of values = 14
# Row 35: Number of values = 14
# Row 36: Number of values = 14
# Row 37: Number of values = 14
# Row 38: Number of values = 14
# Row 39: Number of values = 14
# Row 40: Number of values = 14
# Row 41: Number of values = 14
# Row 42: Number of values = 14
# Row 43: Number of values = 14
# Row 44: Number of values = 14
# Row 45: Number of values = 14
# Row 46: Number of values = 14
# Row 47: Number of values = 14
# Row 48: Number of values = 14
# Row 49: Number of values = 14
# Row 50: Number of values = 14
# Row 51: Number of values = 14
# Row 52: Number of values = 14
# Row 53: Number of values = 14
# Row 54: Number of values = 14
# Row 55: Number of values = 14
# Row 56: Number of values = 14
# Row 57: Number of values = 14
# Row 58: Number of values = 14
# Row 59: Number of values = 14
# Row 60: Number of values = 14
# Row 61: Number of values = 14
# Row 62: Number of values = 14
# Row 63: Number of values = 14
# Row 64: Number of values = 14
# Row 65: Number of values = 14
# Row 66: Number of values = 14
# Row 67: Number of values = 14
# Row 68: Number of values = 14
# Row 69: Number of values = 14
# Row 70: Number of values = 14
# Row 71: Number of values = 14
# Row 72: Number of values = 14
# Row 73: Number of values = 14
# Row 74: Number of values = 14
# Row 75: Number of values = 14
# Row 76: Number of values = 14
# Row 77: Number of values = 14
# Row 78: Number of values = 14
# Row 79: Number of values = 14
# Row 80: Number of values = 14
# Row 81: Number of values = 14
# Row 82: Number of values = 14
# Row 83: Number of values = 14
# Row 84: Number of values = 14
# Row 85: Number of values = 14
# Row 86: Number of values = 14
# Row 87: Number of values = 14
# Row 88: Number of values = 14
# Row 89: Number of values = 14
# Row 90: Number of values = 14
# Row 91: Number of values = 14
# Row 92: Number of values = 14
# Row 93: Number of values = 14
# Row 94: Number of values = 14
# Row 95: Number of values = 14
# Row 96: Number of values = 14
# Row 97: Number of values = 14
# Row 98: Number of values = 14
# Row 99: Number of values = 14
# Row 100: Number of values = 14
# Row 101: Number of values = 14
# Row 102: Number of values = 14
# Row 103: Number of values = 14
# Row 104: Number of values = 14
# Row 105: Number of values = 14
# Row 106: Number of values = 14
# Row 107: Number of values = 14
# Row 108: Number of values = 14
# Row 109: Number of values = 14
# Row 110: Number of values = 14
# Row 111: Number of values = 14
# Row 112: Number of values = 14
# Row 113: Number of values = 14
# Row 114: Number of values = 14
# Row 115: Number of values = 14
# Row 116: Number of values = 14
# Row 117: Number of values = 14
# Row 118: Number of values = 14
# Row 119: Number of values = 14
# Row 120: Number of values = 14
# Row 121: Number of values = 14
# Row 122: Number of values = 14
# Row 123: Number of values = 14
# Row 124: Number of values = 14
# Row 125: Number of values = 14
# Row 126: Number of values = 14
# Row 127: Number of values = 14
# Row 128: Number of values = 14
# Row 129: Number of values = 14
# Row 130: Number of values = 14
# Row 131: Number of values = 14
# Row 132: Number of values = 14
# Row 133: Number of values = 14
# Row 134: Number of values = 14
# Row 135: Number of values = 14
# Row 136: Number of values = 14
# Row 137: Number of values = 14
# Row 138: Number of values = 14
# Row 139: Number of values = 14
# Row 140: Number of values = 14
# Row 141: Number of values = 14
# Row 142: Number of values = 14
# Row 143: Number of values = 14
# Row 144: Number of values = 14
# Row 145: Number of values = 14
# Row 146: Number of values = 14
# Row 147: Number of values = 14
# Row 148: Number of values = 14
# Row 149: Number of values = 14
# Row 150: Number of values = 14
# Row 151: Number of values = 14
# Row 152: Number of values = 14
# Row 153: Number of values = 14
# Row 154: Number of values = 14
# Row 155: Number of values = 14
# Row 156: Number of values = 14
# Row 157: Number of values = 14
# Row 158: Number of values = 14
# Row 159: Number of values = 14
# Row 160: Number of values = 14
# Row 161: Number of values = 14
# Row 162: Number of values = 14
# Row 163: Number of values = 14
# Row 164: Number of values = 14
# Row 165: Number of values = 14
# Row 166: Number of values = 14
# Row 167: Number of values = 14
# Row 168: Number of values = 14
# Row 169: Number of values = 14
# Row 170: Number of values = 14
# Row 171: Number of values = 14
# Row 172: Number of values = 14
# Row 173: Number of values = 14
# Row 174: Number of values = 14
# Row 175: Number of values = 14
# Row 176: Number of values = 14
# Row 177: Number of values = 14
# Row 178: Number of values = 14
# Row 179: Number of values = 14
# Row 180: Number of values = 14
# Row 181: Number of values = 14
# Row 182: Number of values = 14
# Row 183: Number of values = 14
# Row 184: Number of values = 14
# Row 185: Number of values = 14
# Row 186: Number of values = 14
# Row 187: Number of values = 14
# Row 188: Number of values = 14
# Row 189: Number of values = 14
# Row 190: Number of values = 14
# Row 191: Number of values = 14
# Row 192: Number of values = 14
# Row 193: Number of values = 14
# Row 194: Number of values = 14
# Row 195: Number of values = 14
# Row 196: Number of values = 14
# Row 197: Number of values = 14
# Row 198: Number of values = 14
# Row 199: Number of values = 14
# Row 200: Number of values = 14
# Row 201: Number of values = 14
# Row 202: Number of values = 14
# Row 203: Number of values = 14
# Row 204: Number of values = 14
# Row 205: Number of values = 14
# Row 206: Number of values = 14
# Row 207: Number of values = 14
# Row 208: Number of values = 14
# Row 209: Number of values = 14
# Row 210: Number of values = 14
# Row 211: Number of values = 14
# Row 212: Number of values = 14
# Row 213: Number of values = 14
# Row 214: Number of values = 14
# Row 215: Number of values = 14
# Row 216: Number of values = 14
# Row 217: Number of values = 14
# Row 218: Number of values = 14
# Row 219: Number of values = 14
# Row 220: Number of values = 14
# Row 221: Number of values = 14
# Row 222: Number of values = 14
# Row 223: Number of values = 14
# Row 224: Number of values = 14
# Row 225: Number of values = 14
# Row 226: Number of values = 14
# Row 227: Number of values = 14
# Row 228: Number of values = 14
# Row 229: Number of values = 14
# Row 230: Number of values = 14
# Row 231: Number of values = 14
# Row 232: Number of values = 14
# Row 233: Number of values = 14
# Row 234: Number of values = 14
# Row 235: Number of values = 14
# Row 236: Number of values = 14
# Row 237: Number of values = 14
# Row 238: Number of values = 14
# Row 239: Number of values = 14
# Row 240: Number of values = 14
# Row 241: Number of values = 14
# Row 242: Number of values = 14
# Row 243: Number of values = 14
# Row 244: Number of values = 14
# Row 245: Number of values = 14
# Row 246: Number of values = 14
# Row 247: Number of values = 14
# Row 248: Number of values = 14
# Row 249: Number of values = 14
# Row 250: Number of values = 14
# Row 251: Number of values = 14
# Row 252: Number of values = 14
# Row 253: Number of values = 14
# Row 254: Number of values = 14
# Row 255: Number of values = 14
# Row 256: Number of values = 14
# Row 257: Number of values = 14
# Row 258: Number of values = 14
# Row 259: Number of values = 14
# Row 260: Number of values = 14
# Row 261: Number of values = 14
# Row 262: Number of values = 14
# Row 263: Number of values = 14
# Row 264: Number of values = 14
# Row 265: Number of values = 14
# Row 266: Number of values = 14
# Row 267: Number of values = 14
# Row 268: Number of values = 14
# Row 269: Number of values = 14
# Row 270: Number of values = 14
# Row 271: Number of values = 14
# Row 272: Number of values = 14
# Row 273: Number of values = 14
# Row 274: Number of values = 14
# Row 275: Number of values = 14
# Row 276: Number of values = 14
# Row 277: Number of values = 14
# Row 278: Number of values = 14
# Row 279: Number of values = 14
# Row 280: Number of values = 14
# Row 281: Number of values = 14
# Row 282: Number of values = 14
# Row 283: Number of values = 14
# Row 284: Number of values = 14
# Row 285: Number of values = 14
# Row 286: Number of values = 14
# Row 287: Number of values = 14
# Row 288: Number of values = 14
# Row 289: Number of values = 14
# Row 290: Number of values = 14
# Row 291: Number of values = 14
# Row 292: Number of values = 14
# Row 293: Number of values = 14
# Row 294: Number of values = 14
# Row 295: Number of values = 14
# Row 296: Number of values = 14
# Row 297: Number of values = 14
# Row 298: Number of values = 14
# Row 299: Number of values = 14
# Row 300: Number of values = 14
# Row 301: Number of values = 14
# Row 302: Number of values = 14
# Row 303: Number of values = 14
# Row 304: Number of values = 14
# Row 305: Number of values = 14
# Row 306: Number of values = 14
# Row 307: Number of values = 14
# Row 308: Number of values = 14
# Row 309: Number of values = 14
# Row 310: Number of values = 14
# Row 311: Number of values = 14
# Row 312: Number of values = 14
# Row 313: Number of values = 14
# Row 314: Number of values = 14
# Row 315: Number of values = 14
# Row 316: Number of values = 14
# Row 317: Number of values = 14
# Row 318: Number of values = 14
# Row 319: Number of values = 14
# Row 320: Number of values = 14
# Row 321: Number of values = 14
# Row 322: Number of values = 14
# Row 323: Number of values = 14
# Row 324: Number of values = 14
# Row 325: Number of values = 14
# Row 326: Number of values = 14
# Row 327: Number of values = 14
# Row 328: Number of values = 14
# Row 329: Number of values = 14
# Row 330: Number of values = 14
# Row 331: Number of values = 14
# Row 332: Number of values = 14
# Row 333: Number of values = 14
# Row 334: Number of values = 14
# Row 335: Number of values = 14
# Row 336: Number of values = 14
# Row 337: Number of values = 14
# Row 338: Number of values = 14
# Row 339: Number of values = 14
# Row 340: Number of values = 14
# Row 341: Number of values = 14
# Row 342: Number of values = 14
# Row 343: Number of values = 14
# Row 344: Number of values = 14
# Row 345: Number of values = 14
# Row 346: Number of values = 14
# Row 347: Number of values = 14
# Row 348: Number of values = 14
# Row 349: Number of values = 14
# Row 350: Number of values = 14
# Row 351: Number of values = 14
# Row 352: Number of values = 14
# Row 353: Number of values = 14
# Row 354: Number of values = 14
# Row 355: Number of values = 14
# Row 356: Number of values = 14
# Row 357: Number of values = 14
# Row 358: Number of values = 14
# Row 359: Number of values = 14
# Row 360: Number of values = 14
# Row 361: Number of values = 14
# Row 362: Number of values = 14
# Row 363: Number of values = 14
# Row 364: Number of values = 14
# Row 365: Number of values = 14
# Row 366: Number of values = 14
# Row 367: Number of values = 14
# Row 368: Number of values = 14
# Row 369: Number of values = 14
# Row 370: Number of values = 14
# Row 371: Number of values = 14
# Row 372: Number of values = 14
# Row 373: Number of values = 14
# Row 374: Number of values = 14
# Row 375: Number of values = 14
# Row 376: Number of values = 14
# Row 377: Number of values = 14
# Row 378: Number of values = 14
# Row 379: Number of values = 14
# Row 380: Number of values = 14
# Row 381: Number of values = 14
# Row 382: Number of values = 14
# Row 383: Number of values = 14
# Row 384: Number of values = 14
# Row 385: Number of values = 14
# Row 386: Number of values = 14
# Row 387: Number of values = 14
# Row 388: Number of values = 14
# Row 389: Number of values = 14
# Row 390: Number of values = 14
# Row 391: Number of values = 14
# Row 392: Number of values = 14
# Row 393: Number of values = 14
# Row 394: Number of values = 14
# Row 395: Number of values = 14
# Row 396: Number of values = 14
# Row 397: Number of values = 14
# Row 398: Number of values = 14
# Row 399: Number of values = 14
# Row 400: Number of values = 14
# Row 401: Number of values = 14
# Row 402: Number of values = 14
# Row 403: Number of values = 14
# Row 404: Number of values = 14
# Row 405: Number of values = 14
# Row 406: Number of values = 14
# Row 407: Number of values = 14
# Row 408: Number of values = 14
# Row 409: Number of values = 14
# Row 410: Number of values = 14
# Row 411: Number of values = 14
# Row 412: Number of values = 14
# Row 413: Number of values = 14
# Row 414: Number of values = 14
# Row 415: Number of values = 14
# Row 416: Number of values = 14
# Row 417: Number of values = 14
# Row 418: Number of values = 14
# Row 419: Number of values = 14
# Row 420: Number of values = 14
# Row 421: Number of values = 14
# Row 422: Number of values = 14
# Row 423: Number of values = 14
# Row 424: Number of values = 14
# Row 425: Number of values = 14
# Row 426: Number of values = 14
# Row 427: Number of values = 14
# Row 428: Number of values = 14
# Row 429: Number of values = 14
# Row 430: Number of values = 14
# Row 431: Number of values = 14
# Row 432: Number of values = 14
# Row 433: Number of values = 14
# Row 434: Number of values = 14
# Row 435: Number of values = 14
# Row 436: Number of values = 14
# Row 437: Number of values = 14
# Row 438: Number of values = 14
# Row 439: Number of values = 14
# Row 440: Number of values = 14
# Row 441: Number of values = 14
# Row 442: Number of values = 14
# Row 443: Number of values = 14
# Row 444: Number of values = 14
# Row 445: Number of values = 14
# Row 446: Number of values = 14
# Row 447: Number of values = 14
# Row 448: Number of values = 14
# Row 449: Number of values = 14
# Row 450: Number of values = 14
# Row 451: Number of values = 14
# Row 452: Number of values = 14
# Row 453: Number of values = 14
# Row 454: Number of values = 14
# Row 455: Number of values = 14
# Row 456: Number of values = 14
# Row 457: Number of values = 14
# Row 458: Number of values = 14
# Row 459: Number of values = 14
# Row 460: Number of values = 14
# Row 461: Number of values = 14
# Row 462: Number of values = 14
# Row 463: Number of values = 14
# Row 464: Number of values = 14
# Row 465: Number of values = 14
# Row 466: Number of values = 14
# Row 467: Number of values = 14
# Row 468: Number of values = 14
# Row 469: Number of values = 14
# Row 470: Number of values = 14
# Row 471: Number of values = 14
# Row 472: Number of values = 14
# Row 473: Number of values = 14
# Row 474: Number of values = 14
# Row 475: Number of values = 14
# Row 476: Number of values = 14
# Row 477: Number of values = 14
# Row 478: Number of values = 14
# Row 479: Number of values = 14
# Row 480: Number of values = 14
# Row 481: Number of values = 14
# Row 482: Number of values = 14
# Row 483: Number of values = 14
# Row 484: Number of values = 14
# Row 485: Number of values = 14
# Row 486: Number of values = 14
# Row 487: Number of values = 14
# Row 488: Number of values = 14
# Row 489: Number of values = 14
# Row 490: Number of values = 14
# Row 491: Number of values = 14
# Row 492: Number of values = 14
# Row 493: Number of values = 14
# Row 494: Number of values = 14
# Row 495: Number of values = 14
# Row 496: Number of values = 14
# Row 497: Number of values = 14
# Row 498: Number of values = 14
# Row 499: Number of values = 14
# Row 500: Number of values = 14
# Row 501: Number of values = 14
# Row 502: Number of values = 14
# Row 503: Number of values = 14
# Row 504: Number of values = 14
# Row 505: Number of values = 14
# Row 506: Number of values = 14
# Row 507: Number of values = 14
# Row 508: Number of values = 14
# Row 509: Number of values = 14
# Row 510: Number of values = 14
# Row 511: Number of values = 14
# Row 512: Number of values = 14
# Row 513: Number of values = 14
# Row 514: Number of values = 14
# Row 515: Number of values = 14
# Row 516: Number of values = 14
# Row 517: Number of values = 14
# Row 518: Number of values = 14
# Row 519: Number of values = 14
# Row 520: Number of values = 14
# Row 521: Number of values = 14
# Row 522: Number of values = 14
# Row 523: Number of values = 14
# Row 524: Number of values = 14
# Row 525: Number of values = 14
# Row 526: Number of values = 14
# Row 527: Number of values = 14
# Row 528: Number of values = 14
# Row 529: Number of values = 14
# Row 530: Number of values = 14
# Row 531: Number of values = 14
# Row 532: Number of values = 14
# Row 533: Number of values = 14
# Row 534: Number of values = 14
# Row 535: Number of values = 14
# Row 536: Number of values = 14
# Row 537: Number of values = 14
# Row 538: Number of values = 14
# Row 539: Number of values = 14
# Row 540: Number of values = 14
# Row 541: Number of values = 14
# Row 542: Number of values = 14
# Row 543: Number of values = 14
# Row 544: Number of values = 14
# Row 545: Number of values = 14
# Row 546: Number of values = 14
# Row 547: Number of values = 14
# Row 548: Number of values = 14
# Row 549: Number of values = 14
# Row 550: Number of values = 14
# Row 551: Number of values = 14
# Row 552: Number of values = 14
# Row 553: Number of values = 14
# Row 554: Number of values = 14
# Row 555: Number of values = 14
# Row 556: Number of values = 14
# Row 557: Number of values = 14
# Row 558: Number of values = 14
# Row 559: Number of values = 14
# Row 560: Number of values = 14
# Row 561: Number of values = 14
# Row 562: Number of values = 14
# Row 563: Number of values = 14
# Row 564: Number of values = 14
# Row 565: Number of values = 14
# Row 566: Number of values = 14
# Row 567: Number of values = 14
# Row 568: Number of values = 14
# Row 569: Number of values = 14
# Row 570: Number of values = 14
# Row 571: Number of values = 14
# Row 572: Number of values = 14
# Row 573: Number of values = 14
# Row 574: Number of values = 14
# Row 575: Number of values = 14
# Row 576: Number of values = 14
# Row 577: Number of values = 14
# Row 578: Number of values = 14
# Row 579: Number of values = 14
# Row 580: Number of values = 14
# Row 581: Number of values = 14
# Row 582: Number of values = 14
# Row 583: Number of values = 14
# Row 584: Number of values = 14
# Row 585: Number of values = 14
# Row 586: Number of values = 14
# Row 587: Number of values = 14
# Row 588: Number of values = 14
# Row 589: Number of values = 14
# Row 590: Number of values = 14
# Row 591: Number of values = 14
# Row 592: Number of values = 14
# Row 593: Number of values = 14
# Row 594: Number of values = 14
# Row 595: Number of values = 14
# Row 596: Number of values = 14
# Row 597: Number of values = 14
# Row 598: Number of values = 14
# Row 599: Number of values = 14
# Row 600: Number of values = 14
# Row 601: Number of values = 14
# Row 602: Number of values = 14
# Row 603: Number of values = 14
# Row 604: Number of values = 14
# Row 605: Number of values = 14
# Row 606: Number of values = 14
# Row 607: Number of values = 14
# Row 608: Number of values = 14
# Row 609: Number of values = 14
# Row 610: Number of values = 14
# Row 611: Number of values = 14
# Row 612: Number of values = 14
# Row 613: Number of values = 14
# Row 614: Number of values = 14
# Row 615: Number of values = 14
# Row 616: Number of values = 14
# Row 617: Number of values = 14
# Row 618: Number of values = 14
# Row 619: Number of values = 14
# Row 620: Number of values = 14
# Row 621: Number of values = 14
# Row 622: Number of values = 14
# Row 623: Number of values = 14
# Row 624: Number of values = 14
# Row 625: Number of values = 14
# Row 626: Number of values = 14
# Row 627: Number of values = 14
# Row 628: Number of values = 14
# Row 629: Number of values = 14
# Row 630: Number of values = 14
# Row 631: Number of values = 14
# Row 632: Number of values = 14
# Row 633: Number of values = 14
# Row 634: Number of values = 14
# Row 635: Number of values = 14
# Row 636: Number of values = 14
# Row 637: Number of values = 14
# Row 638: Number of values = 14
# Row 639: Number of values = 14
# Row 640: Number of values = 14
# Row 641: Number of values = 14
# Row 642: Number of values = 14
# Row 643: Number of values = 14
# Row 644: Number of values = 14
# Row 645: Number of values = 14
# Row 646: Number of values = 14
# Row 647: Number of values = 14
# Row 648: Number of values = 14
# Row 649: Number of values = 14
# Row 650: Number of values = 14
# Row 651: Number of values = 14
# Row 652: Number of values = 14
# Row 653: Number of values = 14
# Row 654: Number of values = 14
# Row 655: Number of values = 14
# Row 656: Number of values = 14
# Row 657: Number of values = 14
# Row 658: Number of values = 14
# Row 659: Number of values = 14
# Row 660: Number of values = 14
# Row 661: Number of values = 14
# Row 662: Number of values = 14
# Row 663: Number of values = 14
# Row 664: Number of values = 14
# Row 665: Number of values = 14
# Row 666: Number of values = 14
# Row 667: Number of values = 14
# Row 668: Number of values = 14
# Row 669: Number of values = 14
# Row 670: Number of values = 14
# Row 671: Number of values = 14
# Row 672: Number of values = 14
# Row 673: Number of values = 14
# Row 674: Number of values = 14
# Row 675: Number of values = 14
# Row 676: Number of values = 14
# Row 677: Number of values = 14
# Row 678: Number of values = 14
# Row 679: Number of values = 14
# Row 680: Number of values = 14
# Row 681: Number of values = 14
# Row 682: Number of values = 14
# Row 683: Number of values = 14
# Row 684: Number of values = 14
# Row 685: Number of values = 14
# Row 686: Number of values = 14
# Row 687: Number of values = 14
# Row 688: Number of values = 14
# Row 689: Number of values = 14
# Row 690: Number of values = 14
# Row 691: Number of values = 14
# Row 692: Number of values = 14
# Row 693: Number of values = 14
# Row 694: Number of values = 14
# Row 695: Number of values = 14
# Row 696: Number of values = 14
# Row 697: Number of values = 14
# Row 698: Number of values = 14
# Row 699: Number of values = 14
# Row 700: Number of values = 14
# Row 701: Number of values = 14
# Row 702: Number of values = 14
# Row 703: Number of values = 14
# Row 704: Number of values = 14
# Row 705: Number of values = 14
# Row 706: Number of values = 14
# Row 707: Number of values = 14
# Row 708: Number of values = 14
# Row 709: Number of values = 14
# Row 710: Number of values = 14
# Row 711: Number of values = 14
# Row 712: Number of values = 14
# Row 713: Number of values = 14
# Row 714: Number of values = 14
# Row 715: Number of values = 14
# Row 716: Number of values = 14
# Row 717: Number of values = 14
# Row 718: Number of values = 14
# Row 719: Number of values = 14
# Row 720: Number of values = 14
# Row 721: Number of values = 14
# Row 722: Number of values = 14
# Row 723: Number of values = 14
# Row 724: Number of values = 14
# Row 725: Number of values = 14
# Row 726: Number of values = 14
# Row 727: Number of values = 14
# Row 728: Number of values = 14
# Row 729: Number of values = 14
# Row 730: Number of values = 14
# Row 731: Number of values = 14
# Row 732: Number of values = 14
# Row 733: Number of values = 14
# Row 734: Number of values = 14
# Row 735: Number of values = 14
# Row 736: Number of values = 14
# Row 737: Number of values = 14
# Row 738: Number of values = 14
# Row 739: Number of values = 14
# Row 740: Number of values = 14
# Row 741: Number of values = 14
# Row 742: Number of values = 14
# Row 743: Number of values = 14
# Row 744: Number of values = 14
# Row 745: Number of values = 14
# Row 746: Number of values = 14
# Row 747: Number of values = 14
# Row 748: Number of values = 14
# Row 749: Number of values = 14
# Row 750: Number of values = 14
# Row 751: Number of values = 14
# Row 752: Number of values = 14
# Row 753: Number of values = 14
# Row 754: Number of values = 14
# Row 755: Number of values = 14
# Row 756: Number of values = 14
# Row 757: Number of values = 14
# Row 758: Number of values = 14
# Row 759: Number of values = 14
# Row 760: Number of values = 14
# Row 761: Number of values = 14
# Row 762: Number of values = 14
# Row 763: Number of values = 14
# Row 764: Number of values = 14
# Row 765: Number of values = 14
# Row 766: Number of values = 14
# Row 767: Number of values = 14
# Row 768: Number of values = 14
# Row 769: Number of values = 14
# Row 770: Number of values = 14
# Row 771: Number of values = 14
# Row 772: Number of values = 14
# Row 773: Number of values = 14
# Row 774: Number of values = 14
# Row 775: Number of values = 14
# Row 776: Number of values = 14
# Row 777: Number of values = 14
# Row 778: Number of values = 14
# Row 779: Number of values = 14
# Row 780: Number of values = 14
# Row 781: Number of values = 14
# Row 782: Number of values = 14
# Row 783: Number of values = 14
# Row 784: Number of values = 14
# Row 785: Number of values = 14
# Row 786: Number of values = 14
# Row 787: Number of values = 14
# Row 788: Number of values = 14
# Row 789: Number of values = 14
# Row 790: Number of values = 14
# Row 791: Number of values = 14
# Row 792: Number of values = 14
# Row 793: Number of values = 14
# Row 794: Number of values = 14
# Row 795: Number of values = 14
# Row 796: Number of values = 14
# Row 797: Number of values = 14
# Row 798: Number of values = 14
# Row 799: Number of values = 14
# Row 800: Number of values = 14
# Row 801: Number of values = 14
# Row 802: Number of values = 14
# Row 803: Number of values = 14
# Row 804: Number of values = 14
# Row 805: Number of values = 14
# Row 806: Number of values = 14
# Row 807: Number of values = 14
# Row 808: Number of values = 14
# Row 809: Number of values = 14
# Row 810: Number of values = 14
# Row 811: Number of values = 14
# Row 812: Number of values = 14
# Row 813: Number of values = 14
# Row 814: Number of values = 14
# Row 815: Number of values = 14
# Row 816: Number of values = 14
# Row 817: Number of values = 14
# Row 818: Number of values = 14
# Row 819: Number of values = 14
# Row 820: Number of values = 14
# Row 821: Number of values = 14
# Row 822: Number of values = 14
# Row 823: Number of values = 14
# Row 824: Number of values = 14
# Row 825: Number of values = 14
# Row 826: Number of values = 14
# Row 827: Number of values = 14
# Row 828: Number of values = 14
# Row 829: Number of values = 14
# Row 830: Number of values = 14
# Row 831: Number of values = 14
# Row 832: Number of values = 14
# Row 833: Number of values = 14
# Row 834: Number of values = 14
# Row 835: Number of values = 14
# Row 836: Number of values = 14
# Row 837: Number of values = 14
# Row 838: Number of values = 14
# Row 839: Number of values = 14
# Row 840: Number of values = 14
# Row 841: Number of values = 14
# Row 842: Number of values = 14
# Row 843: Number of values = 14
# Row 844: Number of values = 14
# Row 845: Number of values = 14
# Row 846: Number of values = 14
# Row 847: Number of values = 14
# Row 848: Number of values = 14
# Row 849: Number of values = 14
# Row 850: Number of values = 14
# Row 851: Number of values = 14
# Row 852: Number of values = 14
# Row 853: Number of values = 14
# Row 854: Number of values = 14
# Row 855: Number of values = 14
# Row 856: Number of values = 14
# Row 857: Number of values = 14
# Row 858: Number of values = 14
# Row 859: Number of values = 14
# Row 860: Number of values = 14
# Row 861: Number of values = 14
# Row 862: Number of values = 14
# Row 863: Number of values = 14
# Row 864: Number of values = 14
# Row 865: Number of values = 14
# Row 866: Number of values = 14
# Row 867: Number of values = 14
# Row 868: Number of values = 14
# Row 869: Number of values = 14
# Row 870: Number of values = 14
# Row 871: Number of values = 14
# Row 872: Number of values = 14
# Row 873: Number of values = 14
# Row 874: Number of values = 14
# Row 875: Number of values = 14
# Row 876: Number of values = 14
# Row 877: Number of values = 14
# Row 878: Number of values = 14
# Row 879: Number of values = 14
# Row 880: Number of values = 14
# Row 881: Number of values = 14
# Row 882: Number of values = 14
# Row 883: Number of values = 14
# Row 884: Number of values = 14
# Row 885: Number of values = 14
# Row 886: Number of values = 14
# Row 887: Number of values = 14
# Row 888: Number of values = 14
# Row 889: Number of values = 14
# Row 890: Number of values = 14
# Row 891: Number of values = 14
# Row 892: Number of values = 14
# Row 893: Number of values = 14
# Row 894: Number of values = 14
# Row 895: Number of values = 14
# Row 896: Number of values = 14
# Row 897: Number of values = 14
# Row 898: Number of values = 14
# Row 899: Number of values = 14
# Row 900: Number of values = 14
# Row 901: Number of values = 14
# Row 902: Number of values = 14
# Row 903: Number of values = 14
# Row 904: Number of values = 14
# Row 905: Number of values = 14
# Row 906: Number of values = 14
# Row 907: Number of values = 14
# Row 908: Number of values = 14
# Row 909: Number of values = 14
# Row 910: Number of values = 14
# Row 911: Number of values = 14
# Row 912: Number of values = 14
# Row 913: Number of values = 14
# Row 914: Number of values = 14
# Row 915: Number of values = 14
# Row 916: Number of values = 14
# Row 917: Number of values = 14
# Row 918: Number of values = 14
# Row 919: Number of values = 14
# Row 920: Number of values = 14
# Row 921: Number of values = 14
# Row 922: Number of values = 14
# Row 923: Number of values = 14
# Row 924: Number of values = 14
# Row 925: Number of values = 14
# Row 926: Number of values = 14
# Row 927: Number of values = 14
# Row 928: Number of values = 14
# Row 929: Number of values = 14
# Row 930: Number of values = 14
# Row 931: Number of values = 14
# Row 932: Number of values = 14
# Row 933: Number of values = 14
# Row 934: Number of values = 14
# Row 935: Number of values = 14
# Row 936: Number of values = 14
# Row 937: Number of values = 14
# Row 938: Number of values = 14
# Row 939: Number of values = 14
# Row 940: Number of values = 14
# Row 941: Number of values = 14
# Row 942: Number of values = 14
# Row 943: Number of values = 14
# Row 944: Number of values = 14
# Row 945: Number of values = 14
# Row 946: Number of values = 14
# Row 947: Number of values = 14
# Row 948: Number of values = 14
# Row 949: Number of values = 14
# Row 950: Number of values = 14
# Row 951: Number of values = 14
# Row 952: Number of values = 14
# Row 953: Number of values = 14
# Row 954: Number of values = 14
# Row 955: Number of values = 14
# Row 956: Number of values = 14
# Row 957: Number of values = 14
# Row 958: Number of values = 14
# Row 959: Number of values = 14
# Row 960: Number of values = 14
# Row 961: Number of values = 14
# Row 962: Number of values = 14
# Row 963: Number of values = 14
# Row 964: Number of values = 14
# Row 965: Number of values = 14
# Row 966: Number of values = 14
# Row 967: Number of values = 14
# Row 968: Number of values = 14
# Row 969: Number of values = 14
# Row 970: Number of values = 14
# Row 971: Number of values = 14
# Row 972: Number of values = 14
# Row 973: Number of values = 14
# Row 974: Number of values = 14
# Row 975: Number of values = 14
# Row 976: Number of values = 14
# Row 977: Number of values = 14
# Row 978: Number of values = 14
# Row 979: Number of values = 14
# Row 980: Number of values = 14
# Row 981: Number of values = 14
# Row 982: Number of values = 14
# Row 983: Number of values = 14
# Row 984: Number of values = 14
# Row 985: Number of values = 14
# Row 986: Number of values = 14
# Row 987: Number of values = 14
# Row 988: Number of values = 14
# Row 989: Number of values = 14
# Row 990: Number of values = 14
# Row 991: Number of values = 14
# Row 992: Number of values = 14
# Row 993: Number of values = 14
# Row 994: Number of values = 14
# Row 995: Number of values = 14
# Row 996: Number of values = 14
# Row 997: Number of values = 14
# Row 998: Number of values = 14
# Row 999: Number of values = 14
# Row 1000: Number of values = 14
# Row 1001: Number of values = 14
# Row 1002: Number of values = 14
# Row 1003: Number of values = 14
# Row 1004: Number of values = 14
# Row 1005: Number of values = 14
# Row 1006: Number of values = 14
# Row 1007: Number of values = 14
# Row 1008: Number of values = 14
# Row 1009: Number of values = 14
# Row 1010: Number of values = 14
# Row 1011: Number of values = 14
# Row 1012: Number of values = 14
# Row 1013: Number of values = 14
# Row 1014: Number of values = 14
# Row 1015: Number of values = 14
# Row 1016: Number of values = 14
# Row 1017: Number of values = 14
# Row 1018: Number of values = 14
# Row 1019: Number of values = 14
# Row 1020: Number of values = 14
# Row 1021: Number of values = 14
# Row 1022: Number of values = 14
# Row 1023: Number of values = 14
# Row 1024: Number of values = 14
# Row 1025: Number of values = 14
# Row 1026: Number of values = 14
# Row 1027: Number of values = 14
# Row 1028: Number of values = 14
# Row 1029: Number of values = 14
# Row 1030: Number of values = 14
# Row 1031: Number of values = 14
# Row 1032: Number of values = 14
# Row 1033: Number of values = 14
# Row 1034: Number of values = 14
# Row 1035: Number of values = 14
# Row 1036: Number of values = 14
# Row 1037: Number of values = 14
# Row 1038: Number of values = 14
# Row 1039: Number of values = 14
# Row 1040: Number of values = 14
# Row 1041: Number of values = 14
# Row 1042: Number of values = 14
# Row 1043: Number of values = 14
# Row 1044: Number of values = 14
# Row 1045: Number of values = 14
# Row 1046: Number of values = 14
# Row 1047: Number of values = 14
# Row 1048: Number of values = 14
# Row 1049: Number of values = 14
# Row 1050: Number of values = 14
# Row 1051: Number of values = 14
# Row 1052: Number of values = 14
# Row 1053: Number of values = 14
# Row 1054: Number of values = 14
# Row 1055: Number of values = 14
# Row 1056: Number of values = 14
# Row 1057: Number of values = 14
# Row 1058: Number of values = 14
# Row 1059: Number of values = 14
# Row 1060: Number of values = 14
# Row 1061: Number of values = 14
# Row 1062: Number of values = 14
# Row 1063: Number of values = 14
# Row 1064: Number of values = 14
# Row 1065: Number of values = 14
# Row 1066: Number of values = 14
# Row 1067: Number of values = 14
# Row 1068: Number of values = 14
# Row 1069: Number of values = 14
# Row 1070: Number of values = 14
# Row 1071: Number of values = 14
# Row 1072: Number of values = 14
# Row 1073: Number of values = 14
# Row 1074: Number of values = 14
# Row 1075: Number of values = 14
# Row 1076: Number of values = 14
# Row 1077: Number of values = 14
# Row 1078: Number of values = 14
# Row 1079: Number of values = 14
# Row 1080: Number of values = 14
# Row 1081: Number of values = 14
# Row 1082: Number of values = 14
# Row 1083: Number of values = 14
# Row 1084: Number of values = 14
# Row 1085: Number of values = 14
# Row 1086: Number of values = 14
# Row 1087: Number of values = 14
# Row 1088: Number of values = 14
# Row 1089: Number of values = 14
# Row 1090: Number of values = 14
# Row 1091: Number of values = 14
# Row 1092: Number of values = 14
# Row 1093: Number of values = 14
# Row 1094: Number of values = 14
# Row 1095: Number of values = 14
# Row 1096: Number of values = 14
# Row 1097: Number of values = 14
# Row 1098: Number of values = 14
# Row 1099: Number of values = 14
# Row 1100: Number of values = 14
# Row 1101: Number of values = 14
# Row 1102: Number of values = 14
# Row 1103: Number of values = 14
# Row 1104: Number of values = 14
# Row 1105: Number of values = 14
# Row 1106: Number of values = 14
# Row 1107: Number of values = 14
# Row 1108: Number of values = 14
# Row 1109: Number of values = 14
# Row 1110: Number of values = 14
# Row 1111: Number of values = 14
# Row 1112: Number of values = 14
# Row 1113: Number of values = 14
# Row 1114: Number of values = 14
# Row 1115: Number of values = 14
# Row 1116: Number of values = 14
# Row 1117: Number of values = 14
# Row 1118: Number of values = 14
# Row 1119: Number of values = 14
# Row 1120: Number of values = 14
# Row 1121: Number of values = 14
# Row 1122: Number of values = 14
# Row 1123: Number of values = 14
# Row 1124: Number of values = 14
# Row 1125: Number of values = 14
# Row 1126: Number of values = 14
# Row 1127: Number of values = 14
# Row 1128: Number of values = 14
# Row 1129: Number of values = 14
# Row 1130: Number of values = 14
# Row 1131: Number of values = 14
# Row 1132: Number of values = 14
# Row 1133: Number of values = 14
# Row 1134: Number of values = 14
# Row 1135: Number of values = 14
# Row 1136: Number of values = 14
# Row 1137: Number of values = 14
# Row 1138: Number of values = 14
# Row 1139: Number of values = 14
# Row 1140: Number of values = 14
# Row 1141: Number of values = 14
# Row 1142: Number of values = 14
# Row 1143: Number of values = 14
# Row 1144: Number of values = 14
# Row 1145: Number of values = 14
# Row 1146: Number of values = 14
# Row 1147: Number of values = 14
# Row 1148: Number of values = 14
# Row 1149: Number of values = 14
# Row 1150: Number of values = 14
# Row 1151: Number of values = 14
# Row 1152: Number of values = 14
# Row 1153: Number of values = 14
# Row 1154: Number of values = 14
# Row 1155: Number of values = 14
# Row 1156: Number of values = 14
# Row 1157: Number of values = 14
# Row 1158: Number of values = 14
# Row 1159: Number of values = 14
# Row 1160: Number of values = 14
# Row 1161: Number of values = 14
# Row 1162: Number of values = 14
# Row 1163: Number of values = 14
# Row 1164: Number of values = 14
# Row 1165: Number of values = 14
# Row 1166: Number of values = 14
# Row 1167: Number of values = 14
# Row 1168: Number of values = 14
# Row 1169: Number of values = 14
# Row 1170: Number of values = 14
# Row 1171: Number of values = 14
# Row 1172: Number of values = 14
# Row 1173: Number of values = 14
# Row 1174: Number of values = 14
# Row 1175: Number of values = 14
# Row 1176: Number of values = 14
# Row 1177: Number of values = 14
# Row 1178: Number of values = 14
# Row 1179: Number of values = 14
# Row 1180: Number of values = 14
# Row 1181: Number of values = 14
# Row 1182: Number of values = 14
# Row 1183: Number of values = 14
# Row 1184: Number of values = 14
# Row 1185: Number of values = 14
# Row 1186: Number of values = 14
# Row 1187: Number of values = 14
# Row 1188: Number of values = 14
# Row 1189: Number of values = 14
# Row 1190: Number of values = 14
# Row 1191: Number of values = 14
# Row 1192: Number of values = 14
# Row 1193: Number of values = 14
# Row 1194: Number of values = 14
# Row 1195: Number of values = 14
# Row 1196: Number of values = 14
# Row 1197: Number of values = 14
# Row 1198: Number of values = 14
# Row 1199: Number of values = 14
# Row 1200: Number of values = 14
# Row 1201: Number of values = 14
# Row 1202: Number of values = 14
# Row 1203: Number of values = 14
# Row 1204: Number of values = 14
# Row 1205: Number of values = 14
# Row 1206: Number of values = 14
# Row 1207: Number of values = 14
# Row 1208: Number of values = 14
# Row 1209: Number of values = 14
# Row 1210: Number of values = 14
# Row 1211: Number of values = 14
# Row 1212: Number of values = 14
# Row 1213: Number of values = 14
# Row 1214: Number of values = 14
# Row 1215: Number of values = 14
# Row 1216: Number of values = 14
# Row 1217: Number of values = 14
# Row 1218: Number of values = 14
# Row 1219: Number of values = 14
# Row 1220: Number of values = 14
# Row 1221: Number of values = 14
# Row 1222: Number of values = 14
# Row 1223: Number of values = 14
# Row 1224: Number of values = 14
# Row 1225: Number of values = 14
# Row 1226: Number of values = 14
# Row 1227: Number of values = 14
# Row 1228: Number of values = 14
# Row 1229: Number of values = 14
# Row 1230: Number of values = 14
# Row 1231: Number of values = 14
# Row 1232: Number of values = 14
# Row 1233: Number of values = 14
# Row 1234: Number of values = 14
# Row 1235: Number of values = 14
# Row 1236: Number of values = 14
# Row 1237: Number of values = 14
# Row 1238: Number of values = 14
# Row 1239: Number of values = 14
# Row 1240: Number of values = 14
# Row 1241: Number of values = 14
# Row 1242: Number of values = 14
# Row 1243: Number of values = 14
# Row 1244: Number of values = 14
# Row 1245: Number of values = 14
# Row 1246: Number of values = 14
# Row 1247: Number of values = 14
# Row 1248: Number of values = 14
# Row 1249: Number of values = 14
# Row 1250: Number of values = 14
# Row 1251: Number of values = 14
# Row 1252: Number of values = 14
# Row 1253: Number of values = 14
# Row 1254: Number of values = 14
# Row 1255: Number of values = 14
# Row 1256: Number of values = 14
# Row 1257: Number of values = 14
# Row 1258: Number of values = 14
# Row 1259: Number of values = 14
# Row 1260: Number of values = 14
# Row 1261: Number of values = 14
# Row 1262: Number of values = 14
# Row 1263: Number of values = 14
# Row 1264: Number of values = 14
# Row 1265: Number of values = 14
# Row 1266: Number of values = 14
# Row 1267: Number of values = 14
# Row 1268: Number of values = 14
# Row 1269: Number of values = 14
# Row 1270: Number of values = 14
# Row 1271: Number of values = 14
# Row 1272: Number of values = 14
# Row 1273: Number of values = 14
# Row 1274: Number of values = 14
# Row 1275: Number of values = 14
# Row 1276: Number of values = 14
# Row 1277: Number of values = 14
# Row 1278: Number of values = 14
# Row 1279: Number of values = 14
# Row 1280: Number of values = 14
# Row 1281: Number of values = 14
# Row 1282: Number of values = 14
# Row 1283: Number of values = 14
# Row 1284: Number of values = 14
# Row 1285: Number of values = 14
# Row 1286: Number of values = 14
# Row 1287: Number of values = 14
# Row 1288: Number of values = 14
# Row 1289: Number of values = 14
# Row 1290: Number of values = 14
# Row 1291: Number of values = 14
# Row 1292: Number of values = 14
# Row 1293: Number of values = 14
# Row 1294: Number of values = 14
# Row 1295: Number of values = 14
# Row 1296: Number of values = 14
# Row 1297: Number of values = 14
# Row 1298: Number of values = 14
# Row 1299: Number of values = 14
# Row 1300: Number of values = 14
# Row 1301: Number of values = 14
# Row 1302: Number of values = 14
# Row 1303: Number of values = 14
# Row 1304: Number of values = 14
# Row 1305: Number of values = 14
# Row 1306: Number of values = 14
# Row 1307: Number of values = 14
# Row 1308: Number of values = 14
# Row 1309: Number of values = 14
# Row 1310: Number of values = 14
# Row 1311: Number of values = 14
# Row 1312: Number of values = 14
# Row 1313: Number of values = 14
# Row 1314: Number of values = 14
# Row 1315: Number of values = 14
# Row 1316: Number of values = 14
# Row 1317: Number of values = 14
# Row 1318: Number of values = 14
# Row 1319: Number of values = 14
# Row 1320: Number of values = 14
# Row 1321: Number of values = 14
# Row 1322: Number of values = 14
# Row 1323: Number of values = 14
# Row 1324: Number of values = 14
# Row 1325: Number of values = 14
# Row 1326: Number of values = 14
# Row 1327: Number of values = 14
# Row 1328: Number of values = 14
# Row 1329: Number of values = 14
# Row 1330: Number of values = 14
# Row 1331: Number of values = 14
# Row 1332: Number of values = 14
# Row 1333: Number of values = 14
# Row 1334: Number of values = 14
# Row 1335: Number of values = 14
# Row 1336: Number of values = 14
# Row 1337: Number of values = 14
# Row 1338: Number of values = 14
# Row 1339: Number of values = 14
# Row 1340: Number of values = 14
# Row 1341: Number of values = 14
# Row 1342: Number of values = 14
# Row 1343: Number of values = 14
# Row 1344: Number of values = 14
# Row 1345: Number of values = 14
# Row 1346: Number of values = 14
# Row 1347: Number of values = 14
# Row 1348: Number of values = 14
# Row 1349: Number of values = 14
# Row 1350: Number of values = 14
# Row 1351: Number of values = 14
# Row 1352: Number of values = 14
# Row 1353: Number of values = 14
# Row 1354: Number of values = 14
# Row 1355: Number of values = 14
# Row 1356: Number of values = 14
# Row 1357: Number of values = 14
# Row 1358: Number of values = 14
# Row 1359: Number of values = 14
# Row 1360: Number of values = 14
# Row 1361: Number of values = 14
# Row 1362: Number of values = 14
# Row 1363: Number of values = 14
# Row 1364: Number of values = 14
# Row 1365: Number of values = 14
# Row 1366: Number of values = 14
# Row 1367: Number of values = 14
# Row 1368: Number of values = 14
# Row 1369: Number of values = 14
# Row 1370: Number of values = 14
# Row 1371: Number of values = 14
# Row 1372: Number of values = 14
# Row 1373: Number of values = 14
# Row 1374: Number of values = 14
# Row 1375: Number of values = 14
# Row 1376: Number of values = 14
# Row 1377: Number of values = 14
# Row 1378: Number of values = 14
# Row 1379: Number of values = 14
# Row 1380: Number of values = 14
# Row 1381: Number of values = 14
# Row 1382: Number of values = 14
# Row 1383: Number of values = 14
# Row 1384: Number of values = 14
# Row 1385: Number of values = 14
# Row 1386: Number of values = 14
# Row 1387: Number of values = 14
# Row 1388: Number of values = 14
# Row 1389: Number of values = 14
# Row 1390: Number of values = 14
# Row 1391: Number of values = 14
# Row 1392: Number of values = 14
# Row 1393: Number of values = 14
# Row 1394: Number of values = 14
# Row 1395: Number of values = 14
# Row 1396: Number of values = 14
# Row 1397: Number of values = 14
# Row 1398: Number of values = 14
# Row 1399: Number of values = 14
# Row 1400: Number of values = 14
# Row 1401: Number of values = 14
# Row 1402: Number of values = 14
# Row 1403: Number of values = 14
# Row 1404: Number of values = 14
# Row 1405: Number of values = 14
# Row 1406: Number of values = 14
# Row 1407: Number of values = 14
# Row 1408: Number of values = 14
# Row 1409: Number of values = 14
# Row 1410: Number of values = 14
# Row 1411: Number of values = 14
# Row 1412: Number of values = 14
# Row 1413: Number of values = 14
# Row 1414: Number of values = 14
# Row 1415: Number of values = 14
# Row 1416: Number of values = 14
# Row 1417: Number of values = 14
# Row 1418: Number of values = 14
# Row 1419: Number of values = 14
# Row 1420: Number of values = 14
# Row 1421: Number of values = 14
# Row 1422: Number of values = 14
# Row 1423: Number of values = 14
# Row 1424: Number of values = 14
# Row 1425: Number of values = 14
# Row 1426: Number of values = 14
# Row 1427: Number of values = 14
# Row 1428: Number of values = 14
# Row 1429: Number of values = 14
# Row 1430: Number of values = 14
# Row 1431: Number of values = 14
# Row 1432: Number of values = 14
# Row 1433: Number of values = 14
# Row 1434: Number of values = 14
# Row 1435: Number of values = 14
# Row 1436: Number of values = 14
# Row 1437: Number of values = 14
# Row 1438: Number of values = 14
# Row 1439: Number of values = 14
# Row 1440: Number of values = 14
# Row 1441: Number of values = 14
# Row 1442: Number of values = 14
# Row 1443: Number of values = 14
# Row 1444: Number of values = 14
# Row 1445: Number of values = 14
# Row 1446: Number of values = 14
# Row 1447: Number of values = 14
# Row 1448: Number of values = 14
# Row 1449: Number of values = 14
# Row 1450: Number of values = 14
# Row 1451: Number of values = 14
# Row 1452: Number of values = 14
# Row 1453: Number of values = 14
# Row 1454: Number of values = 14
# Row 1455: Number of values = 14
# Row 1456: Number of values = 14
# Row 1457: Number of values = 14
# Row 1458: Number of values = 14
# Row 1459: Number of values = 14
# Row 1460: Number of values = 14
# Row 1461: Number of values = 14
# Row 1462: Number of values = 14
# Row 1463: Number of values = 14
# Row 1464: Number of values = 14
# Row 1465: Number of values = 14
# Row 1466: Number of values = 14
# Row 1467: Number of values = 14
# Row 1468: Number of values = 14
# Row 1469: Number of values = 14
# Row 1470: Number of values = 14
# Row 1471: Number of values = 14
# Row 1472: Number of values = 14
# Row 1473: Number of values = 14
# Row 1474: Number of values = 14
# Row 1475: Number of values = 14
# Row 1476: Number of values = 14
# Row 1477: Number of values = 14
# Row 1478: Number of values = 14
# Row 1479: Number of values = 14
# Row 1480: Number of values = 14
# Row 1481: Number of values = 14
# Row 1482: Number of values = 14
# Row 1483: Number of values = 14
# Row 1484: Number of values = 14
# Row 1485: Number of values = 14
# Row 1486: Number of values = 14
# Row 1487: Number of values = 14
# Row 1488: Number of values = 14
# Row 1489: Number of values = 14
# Row 1490: Number of values = 14
# Row 1491: Number of values = 14
# Row 1492: Number of values = 14
# Row 1493: Number of values = 14
# Row 1494: Number of values = 14
# Row 1495: Number of values = 14
# Row 1496: Number of values = 14
# Row 1497: Number of values = 14
# Row 1498: Number of values = 14
# Row 1499: Number of values = 14
# Row 1500: Number of values = 14
# Row 1501: Number of values = 14
# Row 1502: Number of values = 14
# Row 1503: Number of values = 14
# Row 1504: Number of values = 14
# Row 1505: Number of values = 14
# Row 1506: Number of values = 14
# Row 1507: Number of values = 14
# Row 1508: Number of values = 14
# Row 1509: Number of values = 14
# Row 1510: Number of values = 14
# Row 1511: Number of values = 14
# Row 1512: Number of values = 14
# Row 1513: Number of values = 14
# Row 1514: Number of values = 14
# Row 1515: Number of values = 14
# Row 1516: Number of values = 14
# Row 1517: Number of values = 14
# Row 1518: Number of values = 14
# Row 1519: Number of values = 14
# Row 1520: Number of values = 14
# Row 1521: Number of values = 14
# Row 1522: Number of values = 14
# Row 1523: Number of values = 14
# Row 1524: Number of values = 14
# Row 1525: Number of values = 14
# Row 1526: Number of values = 14
# Row 1527: Number of values = 14
# Row 1528: Number of values = 14
# Row 1529: Number of values = 14
# Row 1530: Number of values = 14
# Row 1531: Number of values = 14
# Row 1532: Number of values = 14
# Row 1533: Number of values = 14
# ...
# Row 65054: Number of values = 14
# Row 65055: Number of values = 14
# Row 65056: Number of values = 14
# Row 65057: Number of values = 14
# Row 65058: Number of values = 14
# Row 65059: Number of values = 14
# Row 65060: Number of values = 14
# Row 65061: Number of values = 14
# Row 65062: Number of values = 14
# Row 65063: Number of values = 14
# Row 65064: Number of values = 14
# Row 65065: Number of values = 14
# Row 65066: Number of values = 14
# Row 65067: Number of values = 14
# Row 65068: Number of values = 14
# Row 65069: Number of values = 14
# Row 65070: Number of values = 14
# Row 65071: Number of values = 14
# Row 65072: Number of values = 14
# Row 65073: Number of values = 14
# Row 65074: Number of values = 14
# Row 65075: Number of values = 14
# Row 65076: Number of values = 14
# Row 65077: Number of values = 14
# Row 65078: Number of values = 14
# Row 65079: Number of values = 14
# Row 65080: Number of values = 14
# Row 65081: Number of values = 14
# Row 65082: Number of values = 14
# Row 65083: Number of values = 14
# Row 65084: Number of values = 14
# Row 65085: Number of values = 14
# Row 65086: Number of values = 14
# Row 65087: Number of values = 14
# Row 65088: Number of values = 14
# Row 65089: Number of values = 14
# Row 65090: Number of values = 14
# Row 65091: Number of values = 14
# Row 65092: Number of values = 14
# Row 65093: Number of values = 14
# Row 65094: Number of values = 14
# Row 65095: Number of values = 14
# Row 65096: Number of values = 14
# Row 65097: Number of values = 14
# Row 65098: Number of values = 14
# Row 65099: Number of values = 14
# Row 65100: Number of values = 14
# Row 65101: Number of values = 14
# Row 65102: Number of values = 14
# Row 65103: Number of values = 14
# Row 65104: Number of values = 14
# Row 65105: Number of values = 14
# Row 65106: Number of values = 14
# Row 65107: Number of values = 14
# Row 65108: Number of values = 14
# Row 65109: Number of values = 14
# Row 65110: Number of values = 14
# Row 65111: Number of values = 14
# Row 65112: Number of values = 14
# Row 65113: Number of values = 14
# Row 65114: Number of values = 14
# Row 65115: Number of values = 14
# Row 65116: Number of values = 14
# Row 65117: Number of values = 14
# Row 65118: Number of values = 14
# Row 65119: Number of values = 14
# Row 65120: Number of values = 14
# Row 65121: Number of values = 14
# Row 65122: Number of values = 14
# Row 65123: Number of values = 14
# Row 65124: Number of values = 14
# Row 65125: Number of values = 14
# Row 65126: Number of values = 14
# Row 65127: Number of values = 14
# Row 65128: Number of values = 14
# Row 65129: Number of values = 14
# Row 65130: Number of values = 14
# Row 65131: Number of values = 14
# Row 65132: Number of values = 14
# Row 65133: Number of values = 14
# Row 65134: Number of values = 14
# Row 65135: Number of values = 14
# Row 65136: Number of values = 14
# Row 65137: Number of values = 14
# Row 65138: Number of values = 14
# Row 65139: Number of values = 14
# Row 65140: Number of values = 14
# Row 65141: Number of values = 14
# Row 65142: Number of values = 14
# Row 65143: Number of values = 14
# Row 65144: Number of values = 14
# Row 65145: Number of values = 14
# Row 65146: Number of values = 14
# Row 65147: Number of values = 14
# Row 65148: Number of values = 14
# Row 65149: Number of values = 14
# Row 65150: Number of values = 14
# Row 65151: Number of values = 14
# Row 65152: Number of values = 14
# Row 65153: Number of values = 14
# Row 65154: Number of values = 14
# Row 65155: Number of values = 14
# Row 65156: Number of values = 14
# Row 65157: Number of values = 14
# Row 65158: Number of values = 14
# Row 65159: Number of values = 14
# Row 65160: Number of values = 14
# Row 65161: Number of values = 14
# Row 65162: Number of values = 14
# Row 65163: Number of values = 14
# Row 65164: Number of values = 14
# Row 65165: Number of values = 14
# Row 65166: Number of values = 14
# Row 65167: Number of values = 14
# Row 65168: Number of values = 14
# Row 65169: Number of values = 14
# Row 65170: Number of values = 14
# Row 65171: Number of values = 14
# Row 65172: Number of values = 14
# Row 65173: Number of values = 14
# Row 65174: Number of values = 14
# Row 65175: Number of values = 14
# Row 65176: Number of values = 14
# Row 65177: Number of values = 14
# Row 65178: Number of values = 14
# Row 65179: Number of values = 14
# Row 65180: Number of values = 14
# Row 65181: Number of values = 14
# Row 65182: Number of values = 14
# Row 65183: Number of values = 14
# Row 65184: Number of values = 14
# Row 65185: Number of values = 14
# Row 65186: Number of values = 14
# Row 65187: Number of values = 14
# Row 65188: Number of values = 14
# Row 65189: Number of values = 14
# Row 65190: Number of values = 14
# Row 65191: Number of values = 14
# Row 65192: Number of values = 14
# Row 65193: Number of values = 14
# Row 65194: Number of values = 14
# Row 65195: Number of values = 14
# Row 65196: Number of values = 14
# Row 65197: Number of values = 14
# Row 65198: Number of values = 14
# Row 65199: Number of values = 14
# Row 65200: Number of values = 14
# Row 65201: Number of values = 14
# Row 65202: Number of values = 14
# Row 65203: Number of values = 14
# Row 65204: Number of values = 14
# Row 65205: Number of values = 14
# Row 65206: Number of values = 14
# Row 65207: Number of values = 14
# Row 65208: Number of values = 14
# Row 65209: Number of values = 14
# Row 65210: Number of values = 14
# Row 65211: Number of values = 14
# Row 65212: Number of values = 14
# Row 65213: Number of values = 14
# Row 65214: Number of values = 14
# Row 65215: Number of values = 14
# Row 65216: Number of values = 14
# Row 65217: Number of values = 14
# Row 65218: Number of values = 14
# Row 65219: Number of values = 14
# Row 65220: Number of values = 14
# Row 65221: Number of values = 14
# Row 65222: Number of values = 14
# Row 65223: Number of values = 14
# Row 65224: Number of values = 14
# Row 65225: Number of values = 14
# Row 65226: Number of values = 14
# Row 65227: Number of values = 14
# Row 65228: Number of values = 14
# Row 65229: Number of values = 14
# Row 65230: Number of values = 14
# Row 65231: Number of values = 14
# Row 65232: Number of values = 14
# Row 65233: Number of values = 14
# Row 65234: Number of values = 14
# Row 65235: Number of values = 14
# Row 65236: Number of values = 14
# Row 65237: Number of values = 14
# Row 65238: Number of values = 14
# Row 65239: Number of values = 14
# Row 65240: Number of values = 14
# Row 65241: Number of values = 14
# Row 65242: Number of values = 14
# Row 65243: Number of values = 14
# Row 65244: Number of values = 14
# Row 65245: Number of values = 14
# Row 65246: Number of values = 14
# Row 65247: Number of values = 14
# Row 65248: Number of values = 14
# Row 65249: Number of values = 14
# Row 65250: Number of values = 14
# Row 65251: Number of values = 14
# Row 65252: Number of values = 14
# Row 65253: Number of values = 14
# Row 65254: Number of values = 14
# Row 65255: Number of values = 14
# Row 65256: Number of values = 14
# Row 65257: Number of values = 14
# Row 65258: Number of values = 14
# Row 65259: Number of values = 14
# Row 65260: Number of values = 14
# Row 65261: Number of values = 14
# Row 65262: Number of values = 14
# Row 65263: Number of values = 14
# Row 65264: Number of values = 14
# Row 65265: Number of values = 14
# Row 65266: Number of values = 14
# Row 65267: Number of values = 14
# Row 65268: Number of values = 14
# Row 65269: Number of values = 14
# Row 65270: Number of values = 14
# Row 65271: Number of values = 14
# Row 65272: Number of values = 14
# Row 65273: Number of values = 14
# Row 65274: Number of values = 14
# Row 65275: Number of values = 14
# Row 65276: Number of values = 14
# Row 65277: Number of values = 14
# Row 65278: Number of values = 14
# Row 65279: Number of values = 14
# Row 65280: Number of values = 14
# Row 65281: Number of values = 14
# Row 65282: Number of values = 14
# Row 65283: Number of values = 14
# Row 65284: Number of values = 14
# Row 65285: Number of values = 14
# Row 65286: Number of values = 14
# Row 65287: Number of values = 14
# Row 65288: Number of values = 14
# Row 65289: Number of values = 14
# Row 65290: Number of values = 14
# Row 65291: Number of values = 14
# Row 65292: Number of values = 14
# Row 65293: Number of values = 14
# Row 65294: Number of values = 14
# Row 65295: Number of values = 14
# Row 65296: Number of values = 14
# Row 65297: Number of values = 14
# Row 65298: Number of values = 14
# Row 65299: Number of values = 14
# Row 65300: Number of values = 14
# Row 65301: Number of values = 14
# Row 65302: Number of values = 14
# Row 65303: Number of values = 14
# Row 65304: Number of values = 14
# Row 65305: Number of values = 14
# Row 65306: Number of values = 14
# Row 65307: Number of values = 14
# Row 65308: Number of values = 14
# Row 65309: Number of values = 14
# Row 65310: Number of values = 14
# Row 65311: Number of values = 14
# Row 65312: Number of values = 14
# Row 65313: Number of values = 14
# Row 65314: Number of values = 14
# Row 65315: Number of values = 14
# Row 65316: Number of values = 14
# Row 65317: Number of values = 14
# Row 65318: Number of values = 14
# Row 65319: Number of values = 14
# Row 65320: Number of values = 14
# Row 65321: Number of values = 14
# Row 65322: Number of values = 14
# Row 65323: Number of values = 14
# Row 65324: Number of values = 14
# Row 65325: Number of values = 14
# Row 65326: Number of values = 14
# Row 65327: Number of values = 14
# Row 65328: Number of values = 14
# Row 65329: Number of values = 14
# Row 65330: Number of values = 14
# Row 65331: Number of values = 14
# Row 65332: Number of values = 14
# Row 65333: Number of values = 14
# Row 65334: Number of values = 14
# Row 65335: Number of values = 14
# Row 65336: Number of values = 14
# Row 65337: Number of values = 14
# Row 65338: Number of values = 14
# Row 65339: Number of values = 14
# Row 65340: Number of values = 14
# Row 65341: Number of values = 14
# Row 65342: Number of values = 14
# Row 65343: Number of values = 14
# Row 65344: Number of values = 14
# Row 65345: Number of values = 14
# Row 65346: Number of values = 14
# Row 65347: Number of values = 14
# Row 65348: Number of values = 14
# Row 65349: Number of values = 14
# Row 65350: Number of values = 14
# Row 65351: Number of values = 14
# Row 65352: Number of values = 14
# Row 65353: Number of values = 14
# Row 65354: Number of values = 14
# Row 65355: Number of values = 14
# Row 65356: Number of values = 14
# Row 65357: Number of values = 14
# Row 65358: Number of values = 14
# Row 65359: Number of values = 14
# Row 65360: Number of values = 14
# Row 65361: Number of values = 14
# Row 65362: Number of values = 14
# Row 65363: Number of values = 14
# Row 65364: Number of values = 14
# Row 65365: Number of values = 14
# Row 65366: Number of values = 14
# Row 65367: Number of values = 14
# Row 65368: Number of values = 14
# Row 65369: Number of values = 14
# Row 65370: Number of values = 14
# Row 65371: Number of values = 14
# Row 65372: Number of values = 14
# Row 65373: Number of values = 14
# Row 65374: Number of values = 14
# Row 65375: Number of values = 14
# Row 65376: Number of values = 14
# Row 65377: Number of values = 14
# Row 65378: Number of values = 14
# Row 65379: Number of values = 14
# Row 65380: Number of values = 14
# Row 65381: Number of values = 14
# Row 65382: Number of values = 14
# Row 65383: Number of values = 14
# Row 65384: Number of values = 14
# Row 65385: Number of values = 14
# Row 65386: Number of values = 14
# Row 65387: Number of values = 14
# Row 65388: Number of values = 14
# Row 65389: Number of values = 14
# Row 65390: Number of values = 14
# Row 65391: Number of values = 14
# Row 65392: Number of values = 14
# Row 65393: Number of values = 14
# Row 65394: Number of values = 14
# Row 65395: Number of values = 14
# Row 65396: Number of values = 14
# Row 65397: Number of values = 14
# Row 65398: Number of values = 14
# Row 65399: Number of values = 14
# Row 65400: Number of values = 14
# Row 65401: Number of values = 14
# Row 65402: Number of values = 14
# Row 65403: Number of values = 14
# Row 65404: Number of values = 14
# Row 65405: Number of values = 14
# Row 65406: Number of values = 14
# Row 65407: Number of values = 14
# Row 65408: Number of values = 14
# Row 65409: Number of values = 14
# Row 65410: Number of values = 14
# Row 65411: Number of values = 14
# Row 65412: Number of values = 14
# Row 65413: Number of values = 14
# Row 65414: Number of values = 14
# Row 65415: Number of values = 14
# Row 65416: Number of values = 14
# Row 65417: Number of values = 14
# Row 65418: Number of values = 14
# Row 65419: Number of values = 14
# Row 65420: Number of values = 14
# Row 65421: Number of values = 14
# Row 65422: Number of values = 14
# Row 65423: Number of values = 14
# Row 65424: Number of values = 14
# Row 65425: Number of values = 14
# Row 65426: Number of values = 14
# Row 65427: Number of values = 14
# Row 65428: Number of values = 14
# Row 65429: Number of values = 14
# Row 65430: Number of values = 14
# Row 65431: Number of values = 14
# Row 65432: Number of values = 14
# Row 65433: Number of values = 14
# Row 65434: Number of values = 14
# Row 65435: Number of values = 14
# Row 65436: Number of values = 14
# Row 65437: Number of values = 14
# Row 65438: Number of values = 14
# Row 65439: Number of values = 14
# Row 65440: Number of values = 14
# Row 65441: Number of values = 14
# Row 65442: Number of values = 14
# Row 65443: Number of values = 14
# Row 65444: Number of values = 14
# Row 65445: Number of values = 14
# Row 65446: Number of values = 14
# Row 65447: Number of values = 14
# Row 65448: Number of values = 14
# Row 65449: Number of values = 14
# Row 65450: Number of values = 14
# Row 65451: Number of values = 14
# Row 65452: Number of values = 14
# Row 65453: Number of values = 14
# Row 65454: Number of values = 14
# Row 65455: Number of values = 14
# Row 65456: Number of values = 14
# Row 65457: Number of values = 14
# Row 65458: Number of values = 14
# Row 65459: Number of values = 14
# Row 65460: Number of values = 14
# Row 65461: Number of values = 14
# Row 65462: Number of values = 14
# Row 65463: Number of values = 14
# Row 65464: Number of values = 14
# Row 65465: Number of values = 14
# Row 65466: Number of values = 14
# Row 65467: Number of values = 14
# Row 65468: Number of values = 14
# Row 65469: Number of values = 14
# Row 65470: Number of values = 14
# Row 65471: Number of values = 14
# Row 65472: Number of values = 14
# Row 65473: Number of values = 14
# Row 65474: Number of values = 14
# Row 65475: Number of values = 14
# Row 65476: Number of values = 14
# Row 65477: Number of values = 14
# Row 65478: Number of values = 14
# Row 65479: Number of values = 14
# Row 65480: Number of values = 14
# Row 65481: Number of values = 14
# Row 65482: Number of values = 14
# Row 65483: Number of values = 14
# Row 65484: Number of values = 14
# Row 65485: Number of values = 14
# Row 65486: Number of values = 14
# Row 65487: Number of values = 14
# Row 65488: Number of values = 14
# Row 65489: Number of values = 14
# Row 65490: Number of values = 14
# Row 65491: Number of values = 14
# Row 65492: Number of values = 14
# Row 65493: Number of values = 14
# Row 65494: Number of values = 14
# Row 65495: Number of values = 14
# Row 65496: Number of values = 14
# Row 65497: Number of values = 14
# Row 65498: Number of values = 14
# Row 65499: Number of values = 14
# Row 65500: Number of values = 14
# Row 65501: Number of values = 14
# Row 65502: Number of values = 14
# Row 65503: Number of values = 14
# Row 65504: Number of values = 14
# Row 65505: Number of values = 14
# Row 65506: Number of values = 14
# Row 65507: Number of values = 14
# Row 65508: Number of values = 14
# Row 65509: Number of values = 14
# Row 65510: Number of values = 14
# Row 65511: Number of values = 14
# Row 65512: Number of values = 14
# Row 65513: Number of values = 14
# Row 65514: Number of values = 14
# Row 65515: Number of values = 14
# Row 65516: Number of values = 14
# Row 65517: Number of values = 14
# Row 65518: Number of values = 14
# Row 65519: Number of values = 14
# Row 65520: Number of values = 14
# Row 65521: Number of values = 14
# Row 65522: Number of values = 14
# Row 65523: Number of values = 14
# Row 65524: Number of values = 14
# Row 65525: Number of values = 14
# Row 65526: Number of values = 14
# Row 65527: Number of values = 14
# Row 65528: Number of values = 14
# Row 65529: Number of values = 14
# Row 65530: Number of values = 14
# Row 65531: Number of values = 14
# Row 65532: Number of values = 14
# Row 65533: Number of values = 14
# Row 65534: Number of values = 14
# Row 65535: Number of values = 14
# Row 65536: Number of values = 14
# Row 65537: Number of values = 14

# %%
cursor.close()
conn.close()
